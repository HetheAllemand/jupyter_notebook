# %%
# SinglyLinkedList implementation 


class SinglyLinkedList:
    class Node:
        def __init__(self, data):
            self.data = data
            self.next = None
            
    def __init__(self):
        self.head = None

    def append(self, value):
        new_node = self.Node(value)
        if not self.head:
            self.head = new_node
        else:
            current = self.head
            while current.next:
                current = current.next
            current.next = new_node

    def insert(self, index, value):
        pass

    def __str__(self):
        out = "["
        if self.head:
            out += "%s" % self.head.data
            current = self.head.next
            while current:
                out += ", %s" % current.data
                current = current.next
        out += "]"
        return out

# %%
sll = SinglyLinkedList()

print(sll)

sll.append(1)
print(sll)

for number in range(2, 4):
    sll.append(number)
    
print(sll)
# Out:
# []
# [1]
# [1, 2, 3]

# %%
mylist = [1, 2, 3]

mylist.insert(100, 100)

print(mylist)

help(mylist)
# Out:
# [1, 2, 3, 100]
# Help on list object:
#
# class list(object)
#  |  list(iterable=(), /)
#  |
#  |  Built-in mutable sequence.
#  |
#  |  If no argument is given, the constructor creates a new empty list.
#  |  The argument must be an iterable if specified.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __iadd__(self, value, /)
#  |      Implement self+=value.
#  |
#  |  __imul__(self, value, /)
#  |      Implement self*=value.
#  |
# ...

# %%
# must identify self, index, and value

# slef is created in the default node; connect index to self

# must identify the index and the value

# create the object

# insert the index / value after the object

# Pseudocode implementation of insert
# define function insert with parameters index and value:
# create a new Node with provided value
# if the list is empty  // represented by the fact is that self.head is set to none
    # then, simply update with new node's next reference so is points to the head
    # and, update the head reference so it points to our new node. 
# otherwise (else) 
    # // we need to validate that the index is within our list
    # create a veriable to keep track of how many times we've traversed (moved from one node to the other)
    # count = 0
    # current = self.head OR current is set to the head node
    # create a reference to a previous node (called previous) which starts as none or empty
    # while count does not equal index and there is a next node to traverse into
        # previous is updated to point to the same node as current
        # current is updated to the next node in the sequence
        # add 1 to count
    # if previous was never updated, then, it means there was only one node in my list
        # append the newly created node to my list (use append method)
    #otherwise, if count is equal to the given index:
    # // this means, we were able to find the index within the scope of our list
    # previous' next reference is updated to point to our newly created node
    #out newly created node's next reference is updated to point to current
        #otherwise
        # // this case happens when index > count
        # append the newly created node to my list

# %%
# Doubly Linked List implementation

class DoublyLinkedList:
    class Node:
        def __init___(self, data):
            self.data = data
            self.next = None
            self.prev = None
    def __init__(self):
        self.head = None
        self.tail = None
        self.length = 0
        
    def append(self, value):
        new_node = self.Node(value)
        if self.tail
            self.tail.next = new_node
            new_node.prev = self.tail
            self.length += 1
        if not self.head:
            self.head = new_node
            self.tail = new_node
        else:
            current = self.head
            while current.next:
                current = current.next
            current.next = new_node
            new_node.prev = current
            self.length += 1
            
    def search(self, value):
        if not self.head:
            return False
        else:
            current = self.head
            tail = self.tail
            while current.data != value and current != tail:
                #traverse
                if current.data != value and tail.data != value:
                    current = current.next
                    tail = tail.prev
                else:
                    return True
        return False
    
    
    # implement binary search as a method to this class (DLL)
    def binary_search(self, value):
        pass
    
    
    def __str__(self):
        out = "["
        if self.head:
            out += "%s" % self.head.data
            current = self.head.next
            while current:
                out += ", %s" % current.data
                current = current.next
        out += "]"
        return out

# %%
dll = DoublyLinkedList()

print(dll)

dll.append(1)
print(dll)

for number in range(2, 4):
    dll.append(number)
    
print(dll)
# Out:
# []
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 5
#       1 dll = DoublyLinkedList()
#       3 print(dll)
# ----> 5 dll.append(1)
#       6 print(dll)
#       8 for number in range(2, 4):
#
# Cell In[8], line 13, in DoublyLinkedList.append(self, value)
#      12 def append(self, value):
# ---> 13     new_node = self.Node(value)
#      14     if not self.head:
#      15         self.head = new_node
#
# TypeError: Node() takes no arguments

# %% [markdown]
# # Challenge 1
# ### Given two integers as parameters, create a box. The box must be comprised of "*".
#
# #### Example:
#
# ```
# my function(2, 2) should return:
#
# **
# **
#
# myfunction(3, 3) should return:
# ***
# * *
# ***
#
# myfunction(5, 5) should return:
# *****
# *   *

# %%
#..
